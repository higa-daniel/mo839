# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

import ssl
ssl._create_default_https_context = ssl._create_unverified_context # este import foi necessário por causa de um erro de SSL

# %%
x = np.arange(0.0, 2.0, 0.01)
y = np.sin(2*np.pi*x)

# %%
#cria uma figura
fig, ax = plt.subplots(figsize=(9, 5)) #ax eixo dos graficos
                                       #fig espaço figura
                                       
#configurar figura
ax.plot(x, y, color='r', linestyle='-', label='Label 1', marker='o', markevery=5)
ax.plot(x, np.cos(y), color='b', linestyle='--', label='Label 2', marker='o',markevery=5)
ax.plot(x, np.tan(y), color='g', linestyle=':', label='Label 3', marker='o',markevery=5)

#insere titulo na figura
ax.set_title('Este é o título do Gráfico')
#insere rotulo do eixo x
ax.set_xlabel('Este é o eixo X', size=22)
#insere rotulo do eixo y
ax.set_ylabel('Esté o eixo Y', size=22)
#aplica grid
plt.grid(True, linestyle='--')
#legenda
plt.legend()
#salvar figura
fig.savefig('exemplo_plot_1.png')
#mostrar figura
plt.show(True)

# %%
# Scatter
fig, ax = plt.subplots()
y       = np.exp(x)

ax.scatter(x, y, color='orange', marker='x');
plt.grid(True, linestyle=':')

# %%
# Barras
dict_exemplo = { 'A' : 10,
                 'B' : 25,
                 'C' : 40,
                 'D' : 30
}

fig, ax = plt.subplots()
chaves  = dict_exemplo.keys()
valores = dict_exemplo.values()


ax.bar(chaves, valores, color=['g', 'y', 'r', 'b'], width=0.7, edgecolor='k');
plt.grid(True, linestyle=':')
ax.set_axisbelow(True)

# %%
# Histograma
distribuicao = np.random.randn(1000)

fig, ax      = plt.subplots()
ax.hist(distribuicao, bins=100, color='b', edgecolor='k', alpha=0.5);
plt.grid(True, linestyle=':')
ax.set_axisbelow(True);

# %%
# Subplots
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

ax[0, 0].plot(x, x/2, )
ax[0, 1].scatter(np.random.random(10), np.random.random(10), color='green')
ax[1, 0].bar(chaves, valores, color='orange', edgecolor='k')
ax[1, 1].hist(distribuicao, bins=100, color='red', edgecolor='k', alpha=0.7);

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Barplot
sns.barplot(x='species', y='sepal_width', data=df, palette='viridis')
# Out:
# /var/folders/hc/bkx75gln73s3s39y8r1820d80000gn/T/ipykernel_11505/3514482257.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species', y='sepal_width', data=df, palette='viridis')
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
# Boxplot
sns.boxplot(x='species', y='sepal_width', data=df, width=0.3, palette='magma')
# Out:
# /var/folders/hc/bkx75gln73s3s39y8r1820d80000gn/T/ipykernel_11505/578194349.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_width', data=df, width=0.3, palette='magma')
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
# Violinplot
sns.violinplot(x='species', y='sepal_width', data=df, width=0.7, palette='Reds')
# Out:
# /var/folders/hc/bkx75gln73s3s39y8r1820d80000gn/T/ipykernel_11505/2736973413.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='species', y='sepal_width', data=df, width=0.7, palette='Reds')
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
# Scatterplot
sns.scatterplot(x='petal_length', y='sepal_length', data=df, hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
# Pairplot
sns.pairplot(data=df, hue='species')

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Heatmap
df_new = df.drop('species', axis=1, inplace=True)
sns.heatmap(df.corr()) #calcula a corelação dos atributos
# Out:
# <Axes: >

# %%
# Lineplot
flights = sns.load_dataset("flights")
sns.lineplot(y='passengers', x='year', data=flights)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# # TITANIC DATASET ANALYSIS

# %%
df_raw = sns.load_dataset('titanic')

# %% [markdown]
# 1. Crie um DataFrame utilizando o dataset importado e mostre as 5 primeiras linhas do DataFrame.

# %%
df_raw.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# 2. Verifique se há registros incompletos e caso encontre, faça a remoção desses registros

# %%
na_values = df_raw.isna().sum()
na_values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df = df_raw.dropna(subset = ['age', 'embarked'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     712 non-null    int64
#  1   pclass       712 non-null    int64
#  2   sex          712 non-null    object
#  3   age          712 non-null    float64
#  4   sibsp        712 non-null    int64
#  5   parch        712 non-null    int64
#  6   fare         712 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        712 non-null    category
#  9   who          712 non-null    object
#  10  adult_male   712 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  712 non-null    object
#  13  alive        712 non-null    object
#  14  alone        712 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 70.0+ KB

# %%
print(f"Shape original: {df_raw.shape}")
print(f"Shape após limpeza: {df.shape}")
print(f"Registros removidos: {len(df_raw) - len(df)}")
print("\n")
# Out:
# Shape original: (891, 15)
# Shape após limpeza: (712, 15)
# Registros removidos: 179

# %% [markdown]
# 3. Verifique os tipos dos atributos e apresente a descrição dos atributos numéricos.

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %% [markdown]
# 4. Calcule o total de sobreviventes, idade média dos passageiros, e o número de homens e mulheres a bordo

# %%
total_sobreviventes = (df['alive'] == 'yes').sum()
total_sobreviventes
idade_media = df['age'].mean()
idade_media
# Out:
# np.float64(29.64209269662921)

# %%
print(f'Total de sobreviventes: {total_sobreviventes}')
print(f'Idade média dos sobreviventes: {idade_media}')
# Out:
# Total de sobreviventes: 288
# Idade média dos sobreviventes: 29.64209269662921

# %% [markdown]
# 5. Gere uma visualização para a quantidade de homens e mulheres a bordo

# %%
gender_counts = df['sex'].value_counts().reset_index()
palette = {"male": "#1f77b4", "female": "#ff7f0e"}
sns.barplot(data=gender_counts, x='sex', y='count', palette=palette)
plt.title('Total Number of Passengers by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')
plt.show()
# Out:
# /var/folders/hc/bkx75gln73s3s39y8r1820d80000gn/T/ipykernel_11505/2783486301.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_counts, x='sex', y='count', palette=palette)

# %% [markdown]
# 6. Gere uma visualização que resuma o intevalo das idades dos passageiros considerando seu sexo e se o passageiro sobreviveu.

# %%
# Converte a coluna 'survived' em categórica (0 → "Não", 1 → "Sim")
df['survived'] = df['survived'].map({0: 'Não', 1: 'Sim'})

# Cria o boxplot com paleta personalizada
sns.boxplot(
    data=df,
    x='sex',
    y='age',
    hue='survived',
    palette={'Não': '#e74c3c', 'Sim': '#2ecc71'}  # vermelho e verde
)

# Ajustes do gráfico
plt.title('Distribuição das Idades por Sexo e Sobrevivência')
plt.xlabel('Sexo')
plt.ylabel('Idade')
plt.legend(title='Sobreviveu')
plt.show()
# Out:
# /var/folders/hc/bkx75gln73s3s39y8r1820d80000gn/T/ipykernel_11505/2710631677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['survived'] = df['survived'].map({0: 'Não', 1: 'Sim'})

# %% [markdown]
# 7. Gere uma visualização do tipo boxplot que mostre a tarifa de acordo com a classe dos passageiros

# %%
sns.boxplot(
    data=df,
    x='class',
    y='fare',
    palette='Set3'
)
# Ajustes do gráfico
plt.title('Distribuição das Tarifas por Classe de Passageiro')
plt.xlabel('Classe')
plt.ylabel('Tarifa')
plt.show()
# Out:
# /var/folders/hc/bkx75gln73s3s39y8r1820d80000gn/T/ipykernel_11505/624889186.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# 8. Gere uma visualização que mostre a correlação dos atributos no dataset

# %%
# Seleciona apenas as colunas numéricas
numeric_data = df.select_dtypes(include=['float64', 'int64'])

# Calcula a matriz de correlação
corr = numeric_data.corr()

# Cria o heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr,
    annot=True,         # mostra os valores de correlação
    cmap='coolwarm',    # escala de cores
    fmt='.2f',          # formato dos números
    linewidths=0.5
)

plt.title('Correlação entre os Atributos Numéricos do Dataset Titanic')
plt.show()

# %% [markdown]
# 9. Gere uma visualização que mostre os sobreviventes de acordo com seu sexo e sua classe

# %%
sns.countplot(
    data=df,
    x='class',
    hue='sex',
    palette='Set2',
    hue_order=['male', 'female']
)

plt.title('Passageiros por Classe e Sexo (Sobrevivência Separada)')
plt.xlabel('Classe')
plt.ylabel('Número de Passageiros')
plt.legend(title='Sexo')
plt.show()
